# %%
# Can I check if a string ends with some substring?

# %%
"test"

# %%
d = {"alice": 4, "bob": 2}
d.get("alice")

# %%
d.get("Bob")

# %%
d['bob']

# %%
bool(1)

# %%
bool("")

# %%
bool(None)

# %%
None and 4 < 5

# %%
stop = 5
counter = 1
while counter < stop:
    print("hello")

# %%
a = [1, 2, 3]

# %%
next(a)

# %%
next(iter(a))
